# %%
# Generic inputs for most ML tasks
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn import tree
import graphviz
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier

pd.options.display.float_format = '{:,.2f}'.format

# setup interactive notebook mode
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML

# %%
airline_data = pd.read_csv('./Detailed_Statistics_Arrivals.csv')

weather_syr=pd.read_csv('./Syracuse_weather.csv')

# %%
airline_data
weather_syr.head()
# Out:
#      Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number Origin Airport  \
# 0              UA        01/01/2022           1282      N4901U            IAD
# 1              UA        01/02/2022           1282      N4901U            IAD
# 2              UA        01/03/2022           1282      N893UA            IAD
# 3              UA        01/04/2022           1282      N814UA            IAD
# 4              UA        01/05/2020           2012      N825UA            ORD
# ...           ...               ...            ...         ...            ...
# 1881           UA        12/31/2019           1460      N838UA            EWR
# 1882           UA        12/31/2021            467      N872UA            IAD
# 1883           UA        12/31/2022            604      N801UA            DEN
# 1884           UA        12/31/2022           1998      N23707            ORD
# 1885           UA        12/31/2022           2488      N37427            EWR
#
#      Scheduled Arrival Time Actual Arrival Time  \
# 0                     23:10               00:01
# 1                     23:10               23:27
# 2                     23:10               23:31
# 3                     23:44               01:59
# 4                     21:47               21:55
# ...                     ...                 ...
# 1881                  18:15               18:14
# 1882                  18:38               18:32
# 1883                  14:58               14:46
# 1884                  21:08               20:44
# 1885                  23:14               00:46
#
#       Scheduled Elapsed Time (Minutes)  Actual Elapsed Time (Minutes)  \
# 0                                   70                             76
# 1                                   70                             64
# 2                                   70                             68
# 3                                   69                             89
# 4                                  107                             94
# ...                                ...                            ...
# 1881                                75                             60
# 1882                                78                             68
# 1883                               193                            178
# 1884                               113                             98
# 1885                                75                             73
#
#       Arrival Delay (Minutes) Wheels-on Time  Taxi-In time (Minutes)  \
# 0                          51          23:55                       6
# 1                          17          23:19                       8
# 2                          21          23:25                       6
# 3                         135          01:55                       4
# 4                           8          21:50                       5
# ...                       ...            ...                     ...
# 1881                       -1          18:08                       6
# 1882                       -6          18:27                       5
# 1883                      -12          14:39                       7
# 1884                      -24          20:40                       4
# 1885                       92          00:40                       6
#
#       Delay Carrier (Minutes)  Delay Weather (Minutes)  \
# 0                          23                        0
# 1                          17                        0
# 2                          21                        0
# 3                         115                        0
# 4                           0                        0
# ...                       ...                      ...
# 1881                        0                        0
# 1882                        0                        0
# 1883                        0                        0
# 1884                        0                        0
# 1885                       92                        0
#
#       Delay National Aviation System (Minutes)  Delay Security (Minutes)  \
# 0                                            6                         0
# 1                                            0                         0
# 2                                            0                         0
# 3                                           20                         0
# 4                                            0                         0
# ...                                        ...                       ...
# 1881                                         0                         0
# 1882                                         0                         0
# 1883                                         0                         0
# 1884                                         0                         0
# 1885                                         0                         0
#
#       Delay Late Aircraft Arrival (Minutes)
# 0                                        22
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
# ...                                     ...
# 1881                                      0
# 1882                                      0
# 1883                                      0
# 1884                                      0
# 1885                                      0
#
# [1886 rows x 17 columns]
#    app_temp  azimuth  clouds       datetime  dewpt  dhi  dni  elev_angle  ghi  \
# 0      7.80   354.92     100  2019-01-01:05   4.70 0.00 0.00      -69.87 0.00
# 1      8.90    32.54     100  2019-01-01:06   5.50 0.00 0.00      -67.19 0.00
# 2      9.40    58.16     100  2019-01-01:07   6.70 0.00 0.00      -59.33 0.00
# 3     11.10    74.56     100  2019-01-01:08   7.80 0.00 0.00      -49.29 0.00
# 4     10.60    86.56     100  2019-01-01:09   8.20 0.00 0.00      -38.51 0.00
#
#    h_angle  ...  temp      timestamp_local        timestamp_utc          ts  \
# 0      NaN  ...  7.80  2019-01-01T00:00:00  2019-01-01T05:00:00  1546318800
# 1      NaN  ...  8.90  2019-01-01T01:00:00  2019-01-01T06:00:00  1546322400
# 2      NaN  ...  9.40  2019-01-01T02:00:00  2019-01-01T07:00:00  1546326000
# 3      NaN  ... 11.10  2019-01-01T03:00:00  2019-01-01T08:00:00  1546329600
# 4      NaN  ... 10.60  2019-01-01T04:00:00  2019-01-01T09:00:00  1546333200
#
#     uv   vis                                            weather  wind_dir  \
# 0 0.00 16.00  {'icon': 'r01n', 'description': 'Light rain', ...       170
# 1 0.00 16.00  {'icon': 'c04n', 'description': 'Overcast clou...       200
# 2 0.00 16.00  {'icon': 'c04n', 'description': 'Overcast clou...       180
# 3 0.00 16.00  {'icon': 'c04n', 'description': 'Overcast clou...       200
# 4 0.00 16.00  {'icon': 'c04n', 'description': 'Overcast clou...       230
#
#    wind_gust_spd wind_spd
# 0          10.00     5.10
# 1           9.00     5.10
# 2          11.00     4.60
# 3          13.00     8.20
# 4          17.00     7.20
#
# [5 rows x 28 columns]

# %%
airline_data.isna().sum()
# Out:
# Carrier Code                                 0
# Date (MM/DD/YYYY)                            0
# Flight Number                                0
# Tail Number                                 56
# Origin Airport                               0
# Scheduled Arrival Time                       0
# Actual Arrival Time                          0
# Scheduled Elapsed Time (Minutes)             0
# Actual Elapsed Time (Minutes)                0
# Arrival Delay (Minutes)                      0
# Wheels-on Time                               0
# Taxi-In time (Minutes)                       0
# Delay Carrier (Minutes)                      0
# Delay Weather (Minutes)                      0
# Delay National Aviation System (Minutes)     0
# Delay Security (Minutes)                     0
# Delay Late Aircraft Arrival (Minutes)        0
# dtype: int64

# %%
airline_data.dropna(inplace=True)

# %%
airline_data['Flight Number']=airline_data['Flight Number'].astype(np.int64)
airline_data['Scheduled Elapsed Time (Minutes)']=airline_data['Scheduled Elapsed Time (Minutes)'].astype(np.int64)
airline_data['Actual Elapsed Time (Minutes)']=airline_data['Actual Elapsed Time (Minutes)'].astype(np.int64)
airline_data['Arrival Delay (Minutes)']=airline_data['Arrival Delay (Minutes)'].astype(np.int64)
airline_data['Delay Carrier (Minutes)']=airline_data['Delay Carrier (Minutes)'].astype(np.int64)
airline_data['Delay Weather (Minutes)']=airline_data['Delay Weather (Minutes)'].astype(np.int64)
airline_data['Delay National Aviation System (Minutes)']=airline_data['Delay National Aviation System (Minutes)'].astype(np.int64)
airline_data['Delay Security (Minutes)']=airline_data['Delay Security (Minutes)'].astype(np.int64)
airline_data['Delay Late Aircraft Arrival (Minutes)']=airline_data['Delay Late Aircraft Arrival (Minutes)'].astype(np.int64)

# %%
airline_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1830 entries, 0 to 1885
# Data columns (total 17 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Carrier Code                              1830 non-null   object
#  1   Date (MM/DD/YYYY)                         1830 non-null   object
#  2   Flight Number                             1830 non-null   int64
#  3   Tail Number                               1830 non-null   object
#  4   Origin Airport                            1830 non-null   object
#  5   Scheduled Arrival Time                    1830 non-null   object
#  6   Actual Arrival Time                       1830 non-null   object
#  7   Scheduled Elapsed Time (Minutes)          1830 non-null   int64
#  8   Actual Elapsed Time (Minutes)             1830 non-null   int64
#  9   Arrival Delay (Minutes)                   1830 non-null   int64
#  10  Wheels-on Time                            1830 non-null   object
#  11  Taxi-In time (Minutes)                    1830 non-null   int64
#  12  Delay Carrier (Minutes)                   1830 non-null   int64
#  13  Delay Weather (Minutes)                   1830 non-null   int64
#  14  Delay National Aviation System (Minutes)  1830 non-null   int64
#  15  Delay Security (Minutes)                  1830 non-null   int64
#  16  Delay Late Aircraft Arrival (Minutes)     1830 non-null   int64
# dtypes: int64(10), object(7)
# memory usage: 257.3+ KB

# %%
airline_data.head()
# Out:
#   Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number Origin Airport  \
# 0           UA        01/01/2022           1282      N4901U            IAD
# 1           UA        01/02/2022           1282      N4901U            IAD
# 2           UA        01/03/2022           1282      N893UA            IAD
# 3           UA        01/04/2022           1282      N814UA            IAD
# 4           UA        01/05/2020           2012      N825UA            ORD
#
#   Scheduled Arrival Time Actual Arrival Time  \
# 0                  23:10               00:01
# 1                  23:10               23:27
# 2                  23:10               23:31
# 3                  23:44               01:59
# 4                  21:47               21:55
#
#    Scheduled Elapsed Time (Minutes)  Actual Elapsed Time (Minutes)  \
# 0                                70                             76
# 1                                70                             64
# 2                                70                             68
# 3                                69                             89
# 4                               107                             94
#
#    Arrival Delay (Minutes) Wheels-on Time  Taxi-In time (Minutes)  \
# 0                       51          23:55                       6
# 1                       17          23:19                       8
# 2                       21          23:25                       6
# 3                      135          01:55                       4
# 4                        8          21:50                       5
#
#    Delay Carrier (Minutes)  Delay Weather (Minutes)  \
# 0                       23                        0
# 1                       17                        0
# 2                       21                        0
# 3                      115                        0
# 4                        0                        0
#
#    Delay National Aviation System (Minutes)  Delay Security (Minutes)  \
# 0                                         6                         0
# 1                                         0                         0
# 2                                         0                         0
# 3                                        20                         0
# 4                                         0                         0
#
#    Delay Late Aircraft Arrival (Minutes)
# 0                                     22
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0

# %%
def set_dependent_variable(time):
    if time<-5:
        return 'Early'
    elif (time>=-5 and time<=5):
        return 'On-time'
    else:
        return 'Late'

# %%
airline_data['Status']=airline_data['Arrival Delay (Minutes)'].apply(set_dependent_variable)

# %%
airline_data.columns
# Out:
# Index(['Carrier Code', 'Date (MM/DD/YYYY)', 'Flight Number', 'Tail Number',
#        'Origin Airport', 'Scheduled Arrival Time', 'Actual Arrival Time',
#        'Scheduled Elapsed Time (Minutes)', 'Actual Elapsed Time (Minutes)',
#        'Arrival Delay (Minutes)', 'Wheels-on Time', 'Taxi-In time (Minutes)',
#        'Delay Carrier (Minutes)', 'Delay Weather (Minutes)',
#        'Delay National Aviation System (Minutes)', 'Delay Security (Minutes)',
#        'Delay Late Aircraft Arrival (Minutes)', 'Status'],
#       dtype='object')

# %%
airline_data.isna().sum()
# Out:
# Carrier Code                                0
# Date (MM/DD/YYYY)                           0
# Flight Number                               0
# Tail Number                                 0
# Origin Airport                              0
# Scheduled Arrival Time                      0
# Actual Arrival Time                         0
# Scheduled Elapsed Time (Minutes)            0
# Actual Elapsed Time (Minutes)               0
# Arrival Delay (Minutes)                     0
# Wheels-on Time                              0
# Taxi-In time (Minutes)                      0
# Delay Carrier (Minutes)                     0
# Delay Weather (Minutes)                     0
# Delay National Aviation System (Minutes)    0
# Delay Security (Minutes)                    0
# Delay Late Aircraft Arrival (Minutes)       0
# Status                                      0
# dtype: int64

# %%
import plotly
plotly.offline.init_notebook_mode(connected=True)
from plotly.graph_objs import *
from plotly import tools
import plotly.graph_objects as go
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
airline_data.columns
# Out:
# Index(['Carrier Code', 'Date (MM/DD/YYYY)', 'Flight Number', 'Tail Number',
#        'Origin Airport', 'Scheduled Arrival Time', 'Actual Arrival Time',
#        'Scheduled Elapsed Time (Minutes)', 'Actual Elapsed Time (Minutes)',
#        'Arrival Delay (Minutes)', 'Wheels-on Time', 'Taxi-In time (Minutes)',
#        'Delay Carrier (Minutes)', 'Delay Weather (Minutes)',
#        'Delay National Aviation System (Minutes)', 'Delay Security (Minutes)',
#        'Delay Late Aircraft Arrival (Minutes)', 'Status'],
#       dtype='object')

# %%
correl = airline_data.corr()

trace = go.Heatmap(z=correl.values,
                  x=correl.index.values,
                  y=correl.columns.values)
data=[trace]
plotly.offline.iplot(data, filename='Airline data heatmap')
# Out:
# <div>                            <div id="a49e136e-055b-4a9c-92e5-a257b05279a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a49e136e-055b-4a9c-92e5-a257b05279a1")) {                    Plotly.newPlot(                        "a49e136e-055b-4a9c-92e5-a257b05279a1",                        [{"x":["Flight Number","Scheduled Elapsed Time (Minutes)","Actual Elapsed Time (Minutes)","Arrival Delay (Minutes)","Taxi-In time (Minutes)","Delay Carrier (Minutes)","Delay Weather (Minutes)","Delay National Aviation System (Minutes)","Delay Security (Minutes)","Delay Late Aircraft Arrival (Minutes)"],"y":["Flight Number","Scheduled Elapsed Time (Minutes)","Actual Elapsed Time (Minutes)","Arrival Delay (Minutes)","Taxi-In time (Minutes)","Delay Carrier (Minutes)","Delay Weather (Minutes)","Delay National Aviation System (Minutes)","Delay Security (Minutes)","Delay Late Aircraft Arrival (Minutes)"],"z":[[1.0,-0.49321963291034315,-0.4588068886079574,0.033660183923927896,0.025956869386410168,0.045146407898122146,0.02553372599120104,-0.04018363417010127,null,0.003162272994354961],[-0.49321963291034315,1.0,0.9442895179671225,-0.05839972513767523,0.010791103835260246,-0.0344101606448665,-0.026668043677645532,0.03744791603684232,null,-0.07342505410364855],[-0.4588068886079574,0.9442895179671225,1.0,-0.00933999974185897,0.10935909647614146,-0.02662598377251866,-0.017420892903391664,0.1905227335540129,null,-0.07191183686818564],[0.033660183923927896,-0.05839972513767523,-0.00933999974185897,1.0,0.017281205477620024,0.5906614695249274,0.46799030700572664,0.21215159461434124,null,0.6721976308876152],[0.025956869386410168,0.010791103835260246,0.10935909647614146,0.017281205477620024,1.0,-0.02094277761691113,-0.0004377049459636162,0.2146092599121994,null,-0.04164820737331921],[0.045146407898122146,-0.0344101606448665,-0.02662598377251866,0.5906614695249274,-0.02094277761691113,1.0,-0.009669881750266103,0.026349170690416843,null,0.104458462824776],[0.02553372599120104,-0.026668043677645532,-0.017420892903391664,0.46799030700572664,-0.0004377049459636162,-0.009669881750266103,1.0,0.01138413354003331,null,0.0004482070272526749],[-0.04018363417010127,0.03744791603684232,0.1905227335540129,0.21215159461434124,0.2146092599121994,0.026349170690416843,0.01138413354003331,1.0,null,0.04926574222070655],[null,null,null,null,null,null,null,null,null,null],[0.003162272994354961,-0.07342505410364855,-0.07191183686818564,0.6721976308876152,-0.04164820737331921,0.104458462824776,0.0004482070272526749,0.04926574222070655,null,1.0]],"type":"heatmap"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colo ...

# %%
airline_data.drop(columns=['Carrier Code',  'Tail Number','Actual Arrival Time',
       'Scheduled Elapsed Time (Minutes)', 'Actual Elapsed Time (Minutes)',
       'Arrival Delay (Minutes)', 'Wheels-on Time', 'Taxi-In time (Minutes)',
       'Delay Carrier (Minutes)', 'Delay Weather (Minutes)',
       'Delay National Aviation System (Minutes)', 'Delay Security (Minutes)',
       'Delay Late Aircraft Arrival (Minutes)'],inplace=True)

# %%
airline_data.columns
# Out:
# Index(['Date (MM/DD/YYYY)', 'Flight Number', 'Origin Airport',
#        'Scheduled Arrival Time', 'Status'],
#       dtype='object')

# %%
airline_data['Date']=airline_data['Date (MM/DD/YYYY)'].astype(np.datetime64)

# %%
airline_data.drop(columns=['Date (MM/DD/YYYY)'],inplace=True)

# %%
airline_data
# Out:
#       Flight Number Origin Airport Scheduled Arrival Time         Status  \
# 0              1282            IAD                  23:10  Severely Late
# 1              1282            IAD                  23:10           Late
# 2              1282            IAD                  23:10           Late
# 3              1282            IAD                  23:44  Severely Late
# 4              2012            ORD                  21:47        On-time
# ...             ...            ...                    ...            ...
# 1881           1460            EWR                  18:15        On-time
# 1882            467            IAD                  18:38        On-time
# 1883            604            DEN                  14:58          Early
# 1884           1998            ORD                  21:08          Early
# 1885           2488            EWR                  23:14  Severely Late
#
#            Date
# 0    2022-01-01
# 1    2022-01-02
# 2    2022-01-03
# 3    2022-01-04
# 4    2020-01-05
# ...         ...
# 1881 2019-12-31
# 1882 2021-12-31
# 1883 2022-12-31
# 1884 2022-12-31
# 1885 2022-12-31
#
# [1830 rows x 5 columns]

# %%
airline_data['Status'].replace("Early",0,inplace=True)

# %%
airline_data['Status'].replace("Severely Late",1,inplace=True)

# %%
airline_data['Status'].replace("Late",2,inplace=True)

# %%
airline_data['Status'].replace("On-time",3,inplace=True)

# %%
set(airline_data['Origin Airport'])
# Out:
# {'DEN', 'EWR', 'IAD', 'ORD'}

# %%
from datetime import datetime

# %%
airline_data['Scheduled Arrival Hour']= pd.to_datetime(airline_data['Scheduled Arrival Time']).dt.hour
airline_data['Scheduled Arrival Minutes']= pd.to_datetime(airline_data['Scheduled Arrival Time']).dt.minute

airline_data
# Out:
#       Flight Number Origin Airport Scheduled Arrival Time  Status       Date  \
# 0              1282            IAD                  23:10       1 2022-01-01
# 1              1282            IAD                  23:10       2 2022-01-02
# 2              1282            IAD                  23:10       2 2022-01-03
# 3              1282            IAD                  23:44       1 2022-01-04
# 4              2012            ORD                  21:47       3 2020-01-05
# ...             ...            ...                    ...     ...        ...
# 1881           1460            EWR                  18:15       3 2019-12-31
# 1882            467            IAD                  18:38       3 2021-12-31
# 1883            604            DEN                  14:58       0 2022-12-31
# 1884           1998            ORD                  21:08       0 2022-12-31
# 1885           2488            EWR                  23:14       1 2022-12-31
#
#       Scheduled Arrival Hour  Scheduled Arrival Minutes
# 0                         23                         10
# 1                         23                         10
# 2                         23                         10
# 3                         23                         44
# 4                         21                         47
# ...                      ...                        ...
# 1881                      18                         15
# 1882                      18                         38
# 1883                      14                         58
# 1884                      21                          8
# 1885                      23                         14
#
# [1830 rows x 7 columns]

# %%
airline_data.drop(columns=['Scheduled Arrival Time'],inplace=True)

# %%
airline_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1830 entries, 0 to 1885
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Flight Number              1830 non-null   int64
#  1   Origin Airport             1830 non-null   object
#  2   Status                     1830 non-null   int64
#  3   Date                       1830 non-null   datetime64[ns]
#  4   Scheduled Arrival Hour     1830 non-null   int64
#  5   Scheduled Arrival Minutes  1830 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 100.1+ KB

# %%
airline_data = pd.get_dummies(airline_data, drop_first = True)
airline_data.head()
# Out:
#    Flight Number  Status       Date  Scheduled Arrival Hour  \
# 0           1282       1 2022-01-01                      23
# 1           1282       2 2022-01-02                      23
# 2           1282       2 2022-01-03                      23
# 3           1282       1 2022-01-04                      23
# 4           2012       3 2020-01-05                      21
#
#    Scheduled Arrival Minutes  Origin Airport_EWR  Origin Airport_IAD  \
# 0                         10                   0                   1
# 1                         10                   0                   1
# 2                         10                   0                   1
# 3                         44                   0                   1
# 4                         47                   0                   0
#
#    Origin Airport_ORD
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   1

# %%
airline_data.drop(columns=['Date'],inplace=True)

# %%
airline_data
# Out:
#       Flight Number  Status  Scheduled Arrival Hour  \
# 0              1282       1                      23
# 1              1282       2                      23
# 2              1282       2                      23
# 3              1282       1                      23
# 4              2012       3                      21
# ...             ...     ...                     ...
# 1881           1460       3                      18
# 1882            467       3                      18
# 1883            604       0                      14
# 1884           1998       0                      21
# 1885           2488       1                      23
#
#       Scheduled Arrival Minutes  Origin Airport_EWR  Origin Airport_IAD  \
# 0                            10                   0                   1
# 1                            10                   0                   1
# 2                            10                   0                   1
# 3                            44                   0                   1
# 4                            47                   0                   0
# ...                         ...                 ...                 ...
# 1881                         15                   1                   0
# 1882                         38                   0                   1
# 1883                         58                   0                   0
# 1884                          8                   0                   0
# 1885                         14                   1                   0
#
#       Origin Airport_ORD
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      1
# ...                  ...
# 1881                   0
# 1882                   0
# 1883                   0
# 1884                   1
# 1885                   0
#
# [1830 rows x 7 columns]

# %%
rf = RandomForestClassifier(random_state=50, min_samples_leaf = 6, max_features = "sqrt", n_estimators = 1000)

rf = rf.fit(airline_data.drop(columns=['Status']), airline_data['Status'])

# %%
test_data=pd.read_csv('./project csv(Apr 12-15).csv')
test_data.drop(columns=['Status (Early, On-time, Late, Severly Late)','Day','Date'],inplace=True)
test_data
# Out:
#    Origin Airport Flight Number Arrival Time
# 0             ORD       UA 3839     10:00 AM
# 1             ORD       UA 3524      4:52 PM
# 2             ORD        UA 538      9:34 PM
# 3             ORD       UA 3839     10:00 AM
# 4             ORD       UA 3524      4:50 PM
# 5             ORD        UA 538      9:34 PM
# 6             ORD       UA 3839     10:00 AM
# 7             ORD       UA 3524      4:50 PM
# 8             ORD        UA 538      9:34 PM
# 9             ORD       UA 3839     10:00 AM
# 10            ORD       UA 3524      4:50 PM
# 11            ORD        UA 538      9:34 PM
# 12            DEN        UA 604      3:12 PM
# 13            DEN        UA 604      3:12 PM
# 14            DEN        UA 604      3:12 PM
# 15            DEN        UA 604      3:12 PM
# 16            EWR       UA 4189     10:46 AM
# 17            EWR       UA 1412     11:42 PM
# 18            EWR       UA 4189     10:46 AM
# 19            EWR       UA 1412     11:42 PM
# 20            EWR       UA 4189     10:46 AM
# 21            EWR       UA 1412     11:42 PM
# 22            EWR       UA 4189     10:46 AM
# 23            EWR       UA 1412     11:17 PM
# 24            IAD       UA 4490      1:57 PM
# 25            IAD       UA 4165      6:59 PM
# 26            IAD       UA 4490      1:57 PM
# 27            IAD       UA 4165      6:59 PM
# 28            IAD       UA 4490      1:57 PM
# 29            IAD       UA 4165      6:59 PM
# 30            IAD       UA 3805      1:58 PM
# 31            IAD       UA 4165      6:59 PM
# 32            NaN           NaN          NaN
# 33            NaN           NaN          NaN
# 34            NaN           NaN          NaN
# 35            NaN           NaN          NaN
# 36            NaN           NaN          NaN
# 37            NaN           NaN          NaN
# 38            NaN           NaN          NaN
# 39            NaN           NaN          NaN
# 40            NaN           NaN          NaN
# 41            NaN           NaN          NaN
# 42            NaN           NaN          NaN
# 43            NaN           NaN          NaN
# 44            NaN           NaN          NaN
# 45            NaN           NaN          NaN
# 46            NaN           NaN          NaN
# 47            NaN           NaN          NaN
# 48            NaN           NaN          NaN
# 49            NaN           NaN          NaN
# 50            NaN           NaN          NaN
# 51            NaN           NaN          NaN
# 52            NaN           NaN          NaN
# 53            NaN           NaN          NaN

# %%
test_data.dropna(inplace=True)

# %%
test_data
# Out:
#    Origin Airport Flight Number Arrival Time
# 0             ORD       UA 3839     10:00 AM
# 1             ORD       UA 3524      4:52 PM
# 2             ORD        UA 538      9:34 PM
# 3             ORD       UA 3839     10:00 AM
# 4             ORD       UA 3524      4:50 PM
# 5             ORD        UA 538      9:34 PM
# 6             ORD       UA 3839     10:00 AM
# 7             ORD       UA 3524      4:50 PM
# 8             ORD        UA 538      9:34 PM
# 9             ORD       UA 3839     10:00 AM
# 10            ORD       UA 3524      4:50 PM
# 11            ORD        UA 538      9:34 PM
# 12            DEN        UA 604      3:12 PM
# 13            DEN        UA 604      3:12 PM
# 14            DEN        UA 604      3:12 PM
# 15            DEN        UA 604      3:12 PM
# 16            EWR       UA 4189     10:46 AM
# 17            EWR       UA 1412     11:42 PM
# 18            EWR       UA 4189     10:46 AM
# 19            EWR       UA 1412     11:42 PM
# 20            EWR       UA 4189     10:46 AM
# 21            EWR       UA 1412     11:42 PM
# 22            EWR       UA 4189     10:46 AM
# 23            EWR       UA 1412     11:17 PM
# 24            IAD       UA 4490      1:57 PM
# 25            IAD       UA 4165      6:59 PM
# 26            IAD       UA 4490      1:57 PM
# 27            IAD       UA 4165      6:59 PM
# 28            IAD       UA 4490      1:57 PM
# 29            IAD       UA 4165      6:59 PM
# 30            IAD       UA 3805      1:58 PM
# 31            IAD       UA 4165      6:59 PM

# %%
set(test_data['Origin Airport'])
# Out:
# {'DEN', 'EWR', 'IAD', 'ORD'}

# %%
airline_data.columns
# Out:
# Index(['Flight Number', 'Status', 'Scheduled Arrival Hour',
#        'Scheduled Arrival Minutes', 'Origin Airport_EWR', 'Origin Airport_IAD',
#        'Origin Airport_ORD'],
#       dtype='object')

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Origin Airport  32 non-null     object
#  1   Flight Number   32 non-null     object
#  2   Arrival Time    32 non-null     object
# dtypes: object(3)
# memory usage: 1.0+ KB

# %%
test_data['Flight Number']=(test_data['Flight Number'].str[3:]).astype(np.int64)
test_data
# Out:
#    Origin Airport  Flight Number Arrival Time
# 0             ORD           3839     10:00 AM
# 1             ORD           3524      4:52 PM
# 2             ORD            538      9:34 PM
# 3             ORD           3839     10:00 AM
# 4             ORD           3524      4:50 PM
# 5             ORD            538      9:34 PM
# 6             ORD           3839     10:00 AM
# 7             ORD           3524      4:50 PM
# 8             ORD            538      9:34 PM
# 9             ORD           3839     10:00 AM
# 10            ORD           3524      4:50 PM
# 11            ORD            538      9:34 PM
# 12            DEN            604      3:12 PM
# 13            DEN            604      3:12 PM
# 14            DEN            604      3:12 PM
# 15            DEN            604      3:12 PM
# 16            EWR           4189     10:46 AM
# 17            EWR           1412     11:42 PM
# 18            EWR           4189     10:46 AM
# 19            EWR           1412     11:42 PM
# 20            EWR           4189     10:46 AM
# 21            EWR           1412     11:42 PM
# 22            EWR           4189     10:46 AM
# 23            EWR           1412     11:17 PM
# 24            IAD           4490      1:57 PM
# 25            IAD           4165      6:59 PM
# 26            IAD           4490      1:57 PM
# 27            IAD           4165      6:59 PM
# 28            IAD           4490      1:57 PM
# 29            IAD           4165      6:59 PM
# 30            IAD           3805      1:58 PM
# 31            IAD           4165      6:59 PM

# %%
test_data['Arrival Time']=(pd.to_datetime(test_data['Arrival Time'].str.strip(), format='%I:%M %p').dt.strftime('%H:%M'))

# %%
test_data['Scheduled Arrival Hour']=pd.to_datetime(test_data['Arrival Time']).dt.hour
test_data['Scheduled Arrival Minutes']=pd.to_datetime(test_data['Arrival Time']).dt.minute

# %%
test_data.drop(columns=['Arrival Time'],inplace=True)
test_data = pd.get_dummies(test_data, drop_first = True)
test_data
# Out:
#     Flight Number  Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0            3839                      10                          0
# 1            3524                      16                         52
# 2             538                      21                         34
# 3            3839                      10                          0
# 4            3524                      16                         50
# 5             538                      21                         34
# 6            3839                      10                          0
# 7            3524                      16                         50
# 8             538                      21                         34
# 9            3839                      10                          0
# 10           3524                      16                         50
# 11            538                      21                         34
# 12            604                      15                         12
# 13            604                      15                         12
# 14            604                      15                         12
# 15            604                      15                         12
# 16           4189                      10                         46
# 17           1412                      23                         42
# 18           4189                      10                         46
# 19           1412                      23                         42
# 20           4189                      10                         46
# 21           1412                      23                         42
# 22           4189                      10                         46
# 23           1412                      23                         17
# 24           4490                      13                         57
# 25           4165                      18                         59
# 26           4490                      13                         57
# 27           4165                      18                         59
# 28           4490                      13                         57
# 29           4165                      18                         59
# 30           3805                      13                         58
# 31           4165                      18                         59
#
#     Origin Airport_EWR  Origin Airport_IAD  Origin Airport_ORD
# 0                    0                   0                   1
# 1                    0                   0                   1
# 2                    0                   0                   1
# 3                    0                   0                   1
# 4                    0                   0                   1
# 5                    0                   0                   1
# 6                    0                   0                   1
# 7                    0                   0                   1
# 8                    0                   0                   1
# 9                    0                   0                   1
# 10                   0                   0                   1
# 11                   0                   0                   1
# 12                   0                   0                   0
# 13                   0                   0                   0
# 14                   0                   0                   0
# 15                   0                   0                   0
# 16                   1                   0                   0
# 17                   1                   0                   0
# 18                   1                   0                   0
# 19                   1                   0                   0
# 20                   1                   0                   0
# 21                   1                   0                   0
# 22                   1                   0                   0
# 23                   1                   0                   0
# 24                   0                   1                   0
# 25                   0                   1                   0
# 26                   0                   1                   0
# 27                   0                   1                   0
# 28                   0                   1                   0
# 29                   0                   1                   0
# 30                   0                   1                   0
# 31                   0                   1                   0

# %%
rf.predict(test_data)
# Out:
# array([3, 3, 3, 3, 0, 3, 3, 0, 3, 3, 0, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3])

# %%
test_output = pd.DataFrame(rf.predict(test_data), index = test_data.index, columns = ['Status'])

test_output.head()
test_data = test_output.merge(test_data, left_index = True, right_index = True)
test_data
# Out:
#    Status
# 0       3
# 1       3
# 2       3
# 3       3
# 4       0
#     Status  Flight Number  Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0        3           3839                      10                          0
# 1        3           3524                      16                         52
# 2        3            538                      21                         34
# 3        3           3839                      10                          0
# 4        0           3524                      16                         50
# 5        3            538                      21                         34
# 6        3           3839                      10                          0
# 7        0           3524                      16                         50
# 8        3            538                      21                         34
# 9        3           3839                      10                          0
# 10       0           3524                      16                         50
# 11       3            538                      21                         34
# 12       3            604                      15                         12
# 13       3            604                      15                         12
# 14       3            604                      15                         12
# 15       3            604                      15                         12
# 16       3           4189                      10                         46
# 17       3           1412                      23                         42
# 18       3           4189                      10                         46
# 19       3           1412                      23                         42
# 20       3           4189                      10                         46
# 21       3           1412                      23                         42
# 22       3           4189                      10                         46
# 23       3           1412                      23                         17
# 24       3           4490                      13                         57
# 25       3           4165                      18                         59
# 26       3           4490                      13                         57
# 27       3           4165                      18                         59
# 28       3           4490                      13                         57
# 29       3           4165                      18                         59
# 30       3           3805                      13                         58
# 31       3           4165                      18                         59
#
#     Origin Airport_EWR  Origin Airport_IAD  Origin Airport_ORD
# 0                    0                   0                   1
# 1                    0                   0                   1
# 2                    0                   0                   1
# 3                    0                   0                   1
# 4                    0                   0                   1
# 5                    0                   0                   1
# 6                    0                   0                   1
# 7                    0                   0                   1
# 8                    0                   0                   1
# 9                    0                   0                   1
# 10                   0                   0                   1
# 11                   0                   0                   1
# 12                   0                   0                   0
# 13                   0                   0                   0
# 14                   0                   0                   0
# 15                   0                   0                   0
# 16                   1                   0                   0
# 17                   1                   0                   0
# 18                   1                   0                   0
# 19                   1                   0                   0
# 20                   1                   0                   0
# 21                   1                   0                   0
# 22                   1                   0                   0
# 23                   1                   0                   0
# 24                   0                   1                   0
# 25                   0                   1                   0
# 26                   0                   1                   0
# 27                   0                   1                   0
# 28                   0                   1                   0
# 29                   0                   1                   0
# 30                   0                   1                   0
# 31                   0                   1                   0

# %%
test_data['Status'].replace(0,"Early",inplace=True)
test_data['Status'].replace(1,"Severely Late",inplace=True)
test_data['Status'].replace(2,"Late",inplace=True)
test_data['Status'].replace(3,"On-time",inplace=True)
test_data
# Out:
#      Status  Flight Number  Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0   On-time           3839                      10                          0
# 1   On-time           3524                      16                         52
# 2   On-time            538                      21                         34
# 3   On-time           3839                      10                          0
# 4     Early           3524                      16                         50
# 5   On-time            538                      21                         34
# 6   On-time           3839                      10                          0
# 7     Early           3524                      16                         50
# 8   On-time            538                      21                         34
# 9   On-time           3839                      10                          0
# 10    Early           3524                      16                         50
# 11  On-time            538                      21                         34
# 12  On-time            604                      15                         12
# 13  On-time            604                      15                         12
# 14  On-time            604                      15                         12
# 15  On-time            604                      15                         12
# 16  On-time           4189                      10                         46
# 17  On-time           1412                      23                         42
# 18  On-time           4189                      10                         46
# 19  On-time           1412                      23                         42
# 20  On-time           4189                      10                         46
# 21  On-time           1412                      23                         42
# 22  On-time           4189                      10                         46
# 23  On-time           1412                      23                         17
# 24  On-time           4490                      13                         57
# 25  On-time           4165                      18                         59
# 26  On-time           4490                      13                         57
# 27  On-time           4165                      18                         59
# 28  On-time           4490                      13                         57
# 29  On-time           4165                      18                         59
# 30  On-time           3805                      13                         58
# 31  On-time           4165                      18                         59
#
#     Origin Airport_EWR  Origin Airport_IAD  Origin Airport_ORD
# 0                    0                   0                   1
# 1                    0                   0                   1
# 2                    0                   0                   1
# 3                    0                   0                   1
# 4                    0                   0                   1
# 5                    0                   0                   1
# 6                    0                   0                   1
# 7                    0                   0                   1
# 8                    0                   0                   1
# 9                    0                   0                   1
# 10                   0                   0                   1
# 11                   0                   0                   1
# 12                   0                   0                   0
# 13                   0                   0                   0
# 14                   0                   0                   0
# 15                   0                   0                   0
# 16                   1                   0                   0
# 17                   1                   0                   0
# 18                   1                   0                   0
# 19                   1                   0                   0
# 20                   1                   0                   0
# 21                   1                   0                   0
# 22                   1                   0                   0
# 23                   1                   0                   0
# 24                   0                   1                   0
# 25                   0                   1                   0
# 26                   0                   1                   0
# 27                   0                   1                   0
# 28                   0                   1                   0
# 29                   0                   1                   0
# 30                   0                   1                   0
# 31                   0                   1                   0

# %%
test_data.to_csv('./output.csv',index=None)
